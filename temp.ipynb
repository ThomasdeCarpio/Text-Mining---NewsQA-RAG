# %%
from src.model_gateway import create_generation_client

client, effective_model = create_generation_client(GENERATOR_MODEL)
models = client.models.list()

sorted(model.id for model in models.data)
